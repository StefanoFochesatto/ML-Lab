# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import matplotlib.pyplot as plt
import plotly.express as px

# %%
cart_label = np.array([
'ENRON',
'HPL',
'DAREN',
'FORWARDED',
'SUBJECT',
'ATTACHED',
'AREN',
'FARMER',
'HP',
'FORWARD',
])
cart_value = np.array([100.00,
67.86,
67.00,
58.81,
58.17,
56.24,
53.51,
50.37,
42.39,
41.15,
])


df = pd.DataFrame({'cart_label': cart_label, 'cart_value': cart_value}, columns=['cart_label', 'cart_value'])

fig = px.bar(df,x='cart_value',y ='cart_label' , orientation='h',
             hover_data=['cart_value'],
             title='Relative Importance CART')
fig.show()

# %%
TreeNet_label = np.array([
'ENRON',
'HTTP',
'ALI',
'HANKS',
'DAREN',
'HPL',
'NOM',
'Z',
'ATTACHED',
'THE'

])
TreeNet_value = np.array(
[100.00,
81.25,
79.87,
58.37,
53.01,
52.56,
42.81,
39.59,
39.32,
38.95,

])


df = pd.DataFrame({'TreeNet_label': TreeNet_label, 'TreeNet_value': TreeNet_value}, columns=['TreeNet_label', 'TreeNet_value'])

fig = px.bar(df,x='TreeNet_value',y ='TreeNet_label' , orientation='h',
             hover_data=['TreeNet_value'],
             title='Relative Importance TreeNet')
fig.show()

# %%
RandomForest_label = np.array([
'HPL',
'ENRON',
'THANKS',
'SUBJECT',
'METER',
'HTTP',
'ATTACHED',
'YOUR',
'SOFT',
'MORE'


])
RandomForest_value = np.array(
[100.00,
80.86,
67.65,
57.06,
51.71,
50.81,
49.93,
49.28,
47.37,
45.81,


])


df = pd.DataFrame({'RandomForest_label': RandomForest_label, 'RandomForest_value': RandomForest_value}, columns=['RandomForest_label', 'RandomForest_value'])

fig = px.bar(df,x='RandomForest_value',y ='RandomForest_label' , orientation='h',
             hover_data=['RandomForest_value'],
             title='Relative Importance RandomForest')
fig.show()
